# %%
# %%HTML
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %% [markdown]
# ### Library

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

import renom as rm
from renom.optimizer import Adam, Adagrad
from renom.cuda import set_cuda_active
# if you would like to use GPU, set True, otherwise you should be set to False
set_cuda_active(False)

# %%
with open('../intermediate_data/prep_for_reg_USDJPY_M15_20100101@000000_20180823@000000.pkl', mode='rb') as f:
    df = pickle.load(f)

# %%
plt.figure(figsize = (30,5))
plt.plot(df.index, df['close'],'-o')
plt.plot(df.index, df[['sma5','sma25','sma50','sma75','sma100','sma500']])
plt.xlim(['2018-08-01', '2018-08-02'])
plt.ylim([111,113])
plt.legend()
plt.show()

# %%
for col in df:
    print(col)
# Out:
# open
# close
# high
# low
# delta_close
# sma5
# sma25
# sma50
# sma75
# sma100
# sma500
# macd
# macdsignal
# macdhist
# rsi
# -3sigma
# -2sigma
# -1sigma
# +1sigma
# +2sigma
# +3sigma
# adx
# +di
# -di
# sar
# tenkan
# kijun
# senko1
# senko2

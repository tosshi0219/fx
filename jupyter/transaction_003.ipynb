# %% [markdown]
# ### Library

# %%
from datetime import datetime, timedelta
import numpy as np
import oandapy
import sys
sys.path.append('/home/toshio/project/fx')
from config import *
from lib.inference import Inference
from lib.trader import Trader
import time
import pickle

ENV = 'practice'
oanda = oandapy.API(environment=ENV, access_token=token)
trader = Trader()
logs = []

#取引単位
volume = 100

#利確、損確の設定
set_profit = 0.1
set_loss = 0.5

#取引回数
transaction_times = 10000

j = 0
jst = 1
while j < transaction_times:
    j +=1
    now = datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')
    print('------transaction_{0:05}------'.format(j))
    print(now)
    inf = Inference()
    pred_delta=float(inf.pred[0][0])
    pred_side = inf.pred_side
    print('1時間後の推定差額は{}'.format(np.round(pred_delta, 4)))
    #現在価格の取得
    current_price = oanda.get_prices(instruments='USD_JPY')['prices'][0]
    current_ask_price = current_price['ask']
    current_bid_price = current_price['bid']

    #現在のポジション確認
    open_trades = oanda.get_trades(account_id)
    if len(open_trades['trades']) == 0:
        current_side = 'zero'
    else:
        #取引からの経過時間が1時間を超えているものを約定させる
        for tr in open_trades['trades']:
            trade_time = datetime.strptime(tr['time'], '%Y-%m-%dT%H:%M:%S.000000Z')
            current_time = datetime.strptime(now,'%Y-%m-%d %H:%M:%S')
            elapsed_time = (current_time - trade_time).seconds/60.0
            print('id:{0},経過時間:{1:0.1f}分'.format(tr['id'],elapsed_time))
            if elapsed_time > 60.0:
                closed_trades = oanda.close_trade(account_id, tr['id'])
                profit = closed_trades['profit']
                print('profit:{}'.format(profit))
        #約定させた後の現在のポジションの確認
        if len(open_trades['trades']) == 0:
            current_side = 'zero'
        else:
            current_side = open_trades['trades'][-1]['side']
    print('現在のポジション:',current_side)

    #利確、損確価格を計算
    buy_take_profit = current_ask_price + set_profit
    buy_stop_loss = current_bid_price - set_loss
    sell_take_profit = current_bid_price - set_profit
    sell_stop_loss = current_ask_price + set_loss

    #zeroポジの場合は、予測ポジションに注文
    #今のポジションと同じ予測ポジションなら注文
    if (current_side == 'zero') & (pred_side == 'buy'):
        print("Let's buy!")
        trader._market_order(pred_side, volume, buy_take_profit, buy_stop_loss)
    elif (current_side == 'zero') & (pred_side == 'sell'):
        print("Let's sell!")
        trader._market_order(pred_side, volume, sell_take_profit, sell_stop_loss)
    elif (current_side == 'buy') & (pred_side == 'buy'):
        print("Let's buy!")
        trader._market_order(pred_side, volume, buy_take_profit, buy_stop_loss)
    elif (current_side == 'sell') & (pred_side == 'sell'):
        print("Let's sell!")
        trader._market_order(pred_side, volume, sell_take_profit, sell_stop_loss)
    else:
        print('do nothing')
        pass
    print('-------------------------------------')
    log = {'time': now,
               'current_ask_price': current_ask_price,
               'current_bid_price': current_bid_price,
               'pred_delta': pred_delta,
               'pred_side': pred_side}
    logs.append(log)
    if j % 50 ==0:
        print('一旦logをpickle化...transaction_{0:05}-{1:05}'.format(jst,j))
        with open ('../log/log_transaction_{0:05}-{1:05}'.format(jst,j), 'wb') as f:
            pickle.dump(logs, f)
        print(len(logs))
        jst = j+1
        logs = []
    time.sleep(60) #5秒に設定中
# Out:
# ------transaction_00001------
# 2018-09-17 12:11:05
# 1時間後の推定差額は-0.0323
# id:11063761765,経過時間:4.8分
# id:11063758718,経過時間:8.0分
# profit:-4.3
# id:11063758229,経過時間:8.2分
# profit:-3.1
# 現在のポジション: buy
# do nothing
# -------------------------------------
# ------transaction_00002------
# 2018-09-17 12:11:20
# 1時間後の推定差額は0.0428
# id:11063761765,経過時間:5.1分
# profit:-4.4
# 現在のポジション: buy
# Let's buy!
# -------------------------------------
# ------transaction_00003------
# 2018-09-17 12:11:32
# 1時間後の推定差額は0.02
# id:11063763133,経過時間:0.1分
# 現在のポジション: buy
# do nothing
# -------------------------------------
# ------transaction_00004------
# 2018-09-17 12:11:39
# 1時間後の推定差額は0.0761
# id:11063763133,経過時間:0.2分
# 現在のポジション: buy
# Let's buy!
# -------------------------------------
# ------transaction_00005------
# 2018-09-17 12:11:47
# 1時間後の推定差額は0.0194
# id:11063763145,経過時間:0.1分
# id:11063763133,経過時間:0.3分
# 現在のポジション: buy
# do nothing
# -------------------------------------
# ------transaction_00006------
# 2018-09-17 12:11:54
# 1時間後の推定差額は-0.0081
# id:11063763145,経過時間:0.2分
# id:11063763133,経過時間:0.5分
# 現在のポジション: buy
# do nothing
# -------------------------------------
# ------transaction_00007------
# 2018-09-17 12:12:01
# 1時間後の推定差額は-0.0284
# id:11063763145,経過時間:0.3分
# id:11063763133,経過時間:0.6分
# 現在のポジション: buy
# do nothing
# -------------------------------------
# ------transaction_00008------
# 2018-09-17 12:12:08
# 1時間後の推定差額は0.0313
# id:11063763145,経過時間:0.4分
# id:11063763133,経過時間:0.7分
# 現在のポジション: buy
# Let's buy!
# -------------------------------------
# ------transaction_00009------
# 2018-09-17 12:12:19
# 1時間後の推定差額は-0.0378
# id:11063763251,経過時間:0.1分
# id:11063763145,経過時間:0.6分
# id:11063763133,経過時間:0.9分
# 現在のポジション: buy
# do nothing
# -------------------------------------
# ------transaction_00010------
# 2018-09-17 12:12:27
# 1時間後の推定差額は0.0757
# id:11063763251,経過時間:0.2分
# id:11063763145,経過時間:0.8分
# id:11063763133,経過時間:1.0分
# 現在のポジション: buy
# Let's buy!
# -------------------------------------
# ------transaction_00011------
# 2018-09-17 12:12:34
# 1時間後の推定差額は0.0154
# id:11063763263,経過時間:0.1分
# id:11063763251,経過時間:0.3分
# id:11063763145,経過時間:0.9分
# id:11063763133,経過時間:1.1分
# 現在のポジション: buy
# do nothing
# -------------------------------------
# ------transaction_00012------
# 2018-09-17 12:12:42
# 1時間後の推定差額は0.0394
# id:11063763263,経過時間:0.2分
# id:11063763251,経過時間:0.5分
# id:11063763145,経過時間:1.0分
# id:11063763133,経過時間:1.2分
# 現在のポジション: buy
# Let's buy!
# -------------------------------------
# ------transaction_00013------
# 2018-09-17 12:12:52
# HTTPSConnectionPool(host='api-fxpractice.oanda.com', port=443): Max retries exceeded with url: /v1/candles?instrument=USD_JPY&granularity=H1&count=89 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f875dc0e048>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution',))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-5a28442484eb> in <module>()
#      32     print('------transaction_{0:05}------'.format(j))
#      33     print(now)
# ---> 34     inf = Inference()
#      35     pred_delta=float(inf.pred[0][0])
#      36     pred_side = inf.pred_side
#
# ~/project/fx/lib/inference.py in __init__(self)
#      30                                     ])
#      31         self.oanda = oandapy.API(environment="practice", access_token=token)
# ---> 32         self.res = self.oanda.get_history(instrument="USD_JPY", granularity=gran, count = look_back + pred_length + 78)
#      33         self.prep = Preprocess(self.res)
#      34         self.df = self.prep.data
#
# ~/py3env/lib/python3.6/site-packages/oandapy/oandapy.py in get_history(self, **params)
#      36         """
#      37         endpoint = 'v1/candles'
# ---> 38         return self.request(endpoint, params=params)
#      39
#      40     """Accounts"""
#
# ~/py3env/lib/python3.6/site-packages/oandapy/oandapy.py in request(self, endpoint, method, params)
#     278
#     279
# --> 280         content = json.loads(content)
#     281
#     282         # error message
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'dict'

# %%
import pickle
logs = []
for j in range(9):
    st = j*50 +1
    end = (j+1)*50
    with open('../log/log_transaction_{0:05}-{1:05}'.format(st,end),'rb') as f:
        logs.append(pickle.load(f))

# %%
cnt_buy = 0
cnt_sell = 0
cnt_zero = 0
for ii in range(9):
    for i in range(50):
        if logs[ii][i]['pred_side'] == 'buy':
            cnt_buy += 1
        elif logs[ii][i]['pred_side'] == 'sell':
            cnt_sell += 1
        elif logs[ii][i]['pred_side'] == 'zero':
            cnt_zero += 1

print('buy:',cnt_buy)
print('sell:',cnt_sell)
print('zero:',cnt_zero)
#         print(logs[ii][i]['time'], logs[ii][i]['pred_side'])
# Out:
# buy: 140
# sell: 123
# zero: 187

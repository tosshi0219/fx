# %%
# %%HTML
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %% [markdown]
# ### Library

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

import renom as rm
from renom.optimizer import Adam, Adagrad
from renom.cuda import set_cuda_active
# if you would like to use GPU, set True, otherwise you should be set to False
set_cuda_active(False)

# %%
def create_dataset(data, look_back, pred_length):
    exp, target = [], []
    for i in range(len(data) - look_back - pred_length):
        exp.append(data[i : i+look_back, :])
        target.append(data[i + look_back : i + look_back + pred_length, 4].T[0])
        
    n_features = np.array(exp).shape[2]
    exp = np.reshape(np.array(exp), [-1, look_back, n_features])
    target = np.reshape(np.array(target), [-1, 1])
    return exp, target

# %%
def split_data(X, y, test_size=0.1):
    pos = int(round(len(X) * (1-test_size)))
    X_train, y_train = X[:pos], y[:pos]
    X_test, y_test = X[pos:], y[pos:]
    return X_train, y_train, X_test, y_test, pos

# %%
gran = 'M15'

# %%
with open('../intermediate_data/prep_for_reg_USDJPY_{}_20100101@000000_20180823@000000.pkl'.format(gran), mode='rb') as f:
    df = pickle.load(f)

# %%
df_std = df.copy()
stds, means = [], []
for col in df:
    std = df[col].std()
    mean = df[col].mean()
    df_std[col] = (df[col] - mean) / std
    stds.append(std)
    means.append(mean)
data = np.array(df_std)

# %%
look_back = 10
pred_length = 1
X, y = create_dataset(data, look_back, pred_length)

# %%
X_train, y_train, X_test, y_test, pos = split_data(X, y)

# %%
sequential = rm.Sequential([
    rm.Lstm(30),
    rm.Lstm(10),
    rm.Dense(pred_length)
])

# %%
batch_size = 1024
epoch = 1000
N = len(X_train)
T = X_train.shape[1]

learning_curve = []
test_learning_curve = []
optimizer = Adagrad()
for i in range(epoch):
    loss = 0
    test_loss = 0
    perm = np.random.permutation(N)
    for j in range(N//batch_size):
        train_batch = X_train[perm[j*batch_size : (j+1)*batch_size]]
        response_batch = y_train[perm[j*batch_size : (j+1)*batch_size]]
        l = 0
        with sequential.train():
            for t in range(T):
                z = sequential(train_batch[:, t, :])
                l = rm.mse(z, response_batch)
            sequential.truncate()
        l.grad().update(optimizer)
        loss += l.as_ndarray()
    loss = loss / (N // batch_size)
    l_test = 0
    for t in range(T):
        z = sequential(X_test[:, t, :])
        l_test = rm.mse(z, y_test)
    sequential.truncate()
    test_loss += l_test.as_ndarray()
    if i % 10 == 0:
        print("epoch:{:04d} loss:{:.5f} test_loss:{:.5f}".format(i, loss, test_loss))
    learning_curve.append(loss)
    test_learning_curve.append(test_loss)
# Out:
# epoch:0000 loss:0.52184 test_loss:0.32307
# epoch:0010 loss:0.51848 test_loss:0.32287
# epoch:0020 loss:0.51786 test_loss:0.32295
# epoch:0030 loss:0.51738 test_loss:0.32312
# epoch:0040 loss:0.51649 test_loss:0.32306
# epoch:0050 loss:0.51597 test_loss:0.32321
# epoch:0060 loss:0.51599 test_loss:0.32308
# epoch:0070 loss:0.51536 test_loss:0.32325
# epoch:0080 loss:0.51546 test_loss:0.32338
# epoch:0090 loss:0.51459 test_loss:0.32358
# epoch:0100 loss:0.51420 test_loss:0.32366
# epoch:0110 loss:0.51366 test_loss:0.32373
# epoch:0120 loss:0.51332 test_loss:0.32373
# epoch:0130 loss:0.51307 test_loss:0.32373
# epoch:0140 loss:0.51183 test_loss:0.32393
# epoch:0150 loss:0.51188 test_loss:0.32386
# epoch:0160 loss:0.51060 test_loss:0.32416
# epoch:0170 loss:0.51089 test_loss:0.32403
# epoch:0180 loss:0.51004 test_loss:0.32419
# epoch:0190 loss:0.50986 test_loss:0.32426
# epoch:0200 loss:0.50905 test_loss:0.32435
# epoch:0210 loss:0.50924 test_loss:0.32438
# epoch:0220 loss:0.50856 test_loss:0.32450
# epoch:0230 loss:0.50801 test_loss:0.32473
# epoch:0240 loss:0.50783 test_loss:0.32475
# epoch:0250 loss:0.50754 test_loss:0.32478
# epoch:0260 loss:0.50620 test_loss:0.32488
# epoch:0270 loss:0.50661 test_loss:0.32495
# epoch:0280 loss:0.50529 test_loss:0.32507
# epoch:0290 loss:0.50596 test_loss:0.32539
# epoch:0300 loss:0.50502 test_loss:0.32532
# epoch:0310 loss:0.50524 test_loss:0.32543
# epoch:0320 loss:0.50544 test_loss:0.32552
# epoch:0330 loss:0.50478 test_loss:0.32570
# epoch:0340 loss:0.50402 test_loss:0.32561
# epoch:0350 loss:0.50406 test_loss:0.32588
# epoch:0360 loss:0.50367 test_loss:0.32583
# epoch:0370 loss:0.50359 test_loss:0.32594
# epoch:0380 loss:0.50326 test_loss:0.32609
# epoch:0390 loss:0.50290 test_loss:0.32619
# epoch:0400 loss:0.49867 test_loss:0.32637
# epoch:0410 loss:0.50212 test_loss:0.32638
# epoch:0420 loss:0.50178 test_loss:0.32655
# epoch:0430 loss:0.50128 test_loss:0.32668
# epoch:0440 loss:0.50115 test_loss:0.32661
# epoch:0450 loss:0.50080 test_loss:0.32678
# epoch:0460 loss:0.50071 test_loss:0.32684
# epoch:0470 loss:0.50049 test_loss:0.32723
# epoch:0480 loss:0.49894 test_loss:0.32710
# epoch:0490 loss:0.49991 test_loss:0.32717
# epoch:0500 loss:0.49841 test_loss:0.32745
# epoch:0510 loss:0.49944 test_loss:0.32740
# epoch:0520 loss:0.49892 test_loss:0.32743
# epoch:0530 loss:0.49899 test_loss:0.32756
# epoch:0540 loss:0.49862 test_loss:0.32781
# epoch:0550 loss:0.49796 test_loss:0.32778
# epoch:0560 loss:0.49794 test_loss:0.32798
# epoch:0570 loss:0.49748 test_loss:0.32787
# epoch:0580 loss:0.49705 test_loss:0.32790
# epoch:0590 loss:0.49703 test_loss:0.32813
# epoch:0600 loss:0.49648 test_loss:0.32820
# epoch:0610 loss:0.49632 test_loss:0.32843
# epoch:0620 loss:0.49601 test_loss:0.32835
# epoch:0630 loss:0.49606 test_loss:0.32826
# epoch:0640 loss:0.49596 test_loss:0.32865
# epoch:0650 loss:0.49545 test_loss:0.32859
# epoch:0660 loss:0.49529 test_loss:0.32858
# epoch:0670 loss:0.49490 test_loss:0.32889
# epoch:0680 loss:0.49469 test_loss:0.32880
# epoch:0690 loss:0.49367 test_loss:0.32891
# epoch:0700 loss:0.49410 test_loss:0.32905
# epoch:0710 loss:0.49396 test_loss:0.32869
# epoch:0720 loss:0.49381 test_loss:0.32902
# epoch:0730 loss:0.49339 test_loss:0.32910
# epoch:0740 loss:0.49290 test_loss:0.32901
# epoch:0750 loss:0.49334 test_loss:0.32890
# epoch:0760 loss:0.49272 test_loss:0.32933
# epoch:0770 loss:0.49255 test_loss:0.32916
# epoch:0780 loss:0.49269 test_loss:0.32922
# epoch:0790 loss:0.49225 test_loss:0.32960
# epoch:0800 loss:0.49219 test_loss:0.32921
# epoch:0810 loss:0.49230 test_loss:0.32924
# epoch:0820 loss:0.49190 test_loss:0.32943
# epoch:0830 loss:0.49162 test_loss:0.32961
# epoch:0840 loss:0.49124 test_loss:0.32962
# epoch:0850 loss:0.49121 test_loss:0.32958
# epoch:0860 loss:0.49164 test_loss:0.32962
# epoch:0870 loss:0.49065 test_loss:0.32990
# epoch:0880 loss:0.49134 test_loss:0.32984
# epoch:0890 loss:0.49036 test_loss:0.32980
# epoch:0900 loss:0.48933 test_loss:0.32988
# epoch:0910 loss:0.49042 test_loss:0.33008
# epoch:0920 loss:0.48651 test_loss:0.33013
# epoch:0930 loss:0.49019 test_loss:0.33011
# epoch:0940 loss:0.49011 test_loss:0.33023
# epoch:0950 loss:0.48957 test_loss:0.33048
# epoch:0960 loss:0.48941 test_loss:0.33047
# epoch:0970 loss:0.48973 test_loss:0.33083
# epoch:0980 loss:0.48974 test_loss:0.33048
# epoch:0990 loss:0.48910 test_loss:0.33075

# %%
plt.figure(figsize=(10, 4))
plt.plot(learning_curve, label='loss')
plt.plot(test_learning_curve, label='test_loss', alpha=0.6)
plt.title('Learning curve')
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.ylim(0, 2)
plt.legend()
plt.grid()

# %%
# predict test value
for t in range(T):
    y_test_pred = sequential(X_test[:, t, :])
sequential.truncate()
for t in range(T):
    y_train_pred = sequential(X_train[:, t, :])
sequential.truncate()

# # convert standardized heating-load to its original unit
y_train = y_train * stds[4] + means[4]
y_train_pred = y_train_pred * stds[4] + means[4]
y_test = y_test * stds[4] + means[4]
y_test_pred = y_test_pred * stds[4] + means[4]

# Root mean squared error
print("Root mean squared error:{}".format(np.sqrt(mean_squared_error(y_test, y_test_pred))))

ulim = 4
llim = -4
plt.figure(figsize=(8, 8))
plt.plot([llim, ulim], [llim, ulim], c='k', alpha=0.6) # diagonal line
plt.scatter(y_train, y_train_pred, label = 'train')
plt.scatter(y_test, y_test_pred, label = 'test')
plt.xlim(llim, ulim)
plt.ylim(llim, ulim)
plt.xlabel('Actual', fontsize=16)
plt.ylabel('Prediction', fontsize=16)
plt.legend()
plt.grid()
# Out:
# Root mean squared error:0.05057410199821884

# %%
train_price = []
tr_p = df['close'][0]
for v in y_train:
    tr_p += v[0]
    train_price.append(tr_p)
    
train_pred_price = []
tr_pr_p = df['close'][0]
for v in y_train_pred:
    tr_pr_p += v[0]
    train_pred_price.append(tr_pr_p)

test_price = []
te_p = df['close'][y_train.shape[0]]
for v in y_test:
    te_p += v[0]
    test_price.append(te_p)
    
test_pred_price = []
te_pr_p = df['close'][y_train.shape[0]]
for v in y_test_pred:
    te_pr_p += v[0]
    test_pred_price.append(te_pr_p)

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[:pos].index, y_train, label = 'train_actual')
plt.plot(df_std[:pos].index, y_train_pred, label = 'train_prediction')
plt.ylabel('delta_close')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test, label = 'test_actual')
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test_pred, label = 'test_prediction')
plt.ylabel('delta_close')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test, label = 'test_actual')
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test_pred, label = 'test_prediction')
plt.ylabel('delta_close')
plt.xlim('2017-10-09','2017-10-10')
plt.ylim(-0.1,0.1)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[:pos].index, train_price, label = 'train_actual')
plt.plot(df_std[:pos].index, train_pred_price, label = 'train_prediction')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, test_price, label = 'test_actual')
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, test_pred_price, label = 'test_prediction')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
true_updown = y_train
true_updown[true_updown > 0.1] = 1
true_updown[true_updown < -0.1] = -1
true_updown[(true_updown > -0.1) & (true_updown < 0.1)] = 0

pred_updown = np.array(y_train_pred)
pred_updown[pred_updown > 0.1] = 1
pred_updown[pred_updown < -0.1] = -1
pred_updown[(pred_updown > -0.1) & (pred_updown < 0.1)] = 0

df_updown = pd.DataFrame(index = df_std[:pos].index, columns = ['true', 'pred'])
df_updown['true'] = true_updown
df_updown['pred'] = pred_updown
df_updown['error'] = np.zeros(df_updown.shape[0])
df_updown.loc[df_updown['true'] == df_updown['pred'],'error'] = 1
df_updown.loc[df_updown['true'] != df_updown['pred'],'error'] = 0
print('correct = ', df_updown[df_updown['error'] == 1].shape[0])
print('not correct = ', df_updown[df_updown['error'] == 0].shape[0])
# Out:
# correct =  180899
# not correct =  14552

# %%
true_updown = y_test
true_updown[true_updown > 0.1] = 1
true_updown[true_updown < -0.1] = -1
true_updown[(true_updown > -0.1) & (true_updown < 0.1)] = 0

pred_updown = np.array(y_test_pred)
pred_updown[pred_updown > 0.1] = 1
pred_updown[pred_updown < -0.1] = -1
pred_updown[(pred_updown > -0.1) & (pred_updown < 0.1)] = 0

df_updown = pd.DataFrame(index = df_std[pos:-1 * (look_back + pred_length)].index, columns = ['true', 'pred'])
df_updown['true'] = true_updown
df_updown['pred'] = pred_updown
df_updown['error'] = np.zeros(df_updown.shape[0])
df_updown.loc[df_updown['true'] == df_updown['pred'],'error'] = 1
df_updown.loc[df_updown['true'] != df_updown['pred'],'error'] = 0
print('correct = ', df_updown[df_updown['error'] == 1].shape[0])
print('not correct = ', df_updown[df_updown['error'] == 0].shape[0])
# Out:
# correct =  20665
# not correct =  1052

# %%
sequential.save("../model/lstm_{}_{}.h5".format(gran, look_back))

# %%
with open('../model/std_scaler_{}.pickle'.format(gran), mode='wb') as f:
    pickle.dump(stds, f)

# %%
with open('../model/mean_scaler_{}.pickle'.format(gran), mode='wb') as f:
    pickle.dump(means, f)

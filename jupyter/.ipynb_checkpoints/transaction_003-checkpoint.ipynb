# %% [markdown]
# ### Library

# %%
from datetime import datetime, timedelta
import numpy as np
import oandapy
import sys
sys.path.append('/Users/toshio/project/fx')
from config import *
from lib.inference import Inference
from lib.trader import Trader
import time

# %%
ENV = 'practice'
oanda = oandapy.API(environment=ENV, access_token=token)
trader = Trader()
logs = []

#取引単位
volume = 100

#利確、損確の設定
set_profit = 0.1
set_loss = 0.5

#取引回数
transaction_times = 1000

# %%
j = 0
while j < transaction_times:
    j +=1
    now = datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')
    print('------transaction_{0:03}------'.format(j))
    print(now)
    inf = Inference()
    pred_delta=float(inf.pred[0][0])
    pred_side = inf.pred_side
    print('1時間後の推定差額は{}'.format(np.round(pred_delta, 4)))
    print('現在のポジション:', pred_side)
    #現在価格の取得
    current_price = oanda.get_prices(instruments='USD_JPY')['prices'][0]
    current_ask_price = current_price['ask']
    current_bid_price = current_price['bid']

    #現在のポジション確認
    open_trades = oanda.get_trades(account_id)
    if len(open_trades['trades']) == 0:
        current_side = 'zero'
    else:
        #取引からの経過時間が1時間を超えているものを約定させる
        for tr in open_trades['trades']:
            trade_time = datetime.strptime(tr['time'], '%Y-%m-%dT%H:%M:%S.000000Z')
            current_time = datetime.strptime(now,'%Y-%m-%d %H:%M:%S')
            elapsed_time = (current_time - trade_time).seconds/3600
            if elapsed_time > 1:
                closed_trades = oanda.close_trade(account_id, tr['id'])
                profit = closed_trades['profit']
                print('profit:{}'.format(profit))
        #約定させた後の現在のポジションの確認
        if len(open_trades['trades']) == 0:
            current_side = 'zero'
        else:
            current_side = open_trades['trades'][-1]['side']
    
    #利確、損確価格を計算
    buy_take_profit = current_ask_price + set_profit
    buy_stop_loss = current_bid_price - set_loss
    sell_take_profit = current_bid_price - set_profit
    sell_stop_loss = current_ask_price + set_loss

    #zeroポジの場合は、予測ポジションに注文
    #今のポジションと同じ予測ポジションなら注文
    if (current_side == 'zero') & (pred_side == 'buy'):
        print("Let's buy!")
        trader._market_order(pred_side, volume, buy_take_profit, buy_stop_loss)
    elif (current_side == 'zero') & (pred_side == 'sell'):
        print("Let's sell!")
        trader._market_order(pred_side, volume, sell_take_profit, sell_stop_loss)
    elif (current_side == 'buy') & (pred_side == 'buy'):
        print("Let's buy!")
        trader._market_order(pred_side, volume, buy_take_profit, buy_stop_loss)        
    elif (current_side == 'sell') & (pred_side == 'sell'):
        print("Let's sell!")
        trader._market_order(pred_side, volume, sell_take_profit, sell_stop_loss)
    else:
        print('do nothing')
        pass
    print('-------------------------------------')
    log = {'time': now,
               'current_ask_price': current_ask_price,
               'current_bid_price': current_bid_price,
               'pred_delta': pred_delta, 
               'pred_side': pred_side}
    logs.append(log)
    time.sleep(5) #5秒に設定中
# Out:
# ------transaction_001------
# 2018-09-17 04:00:55
# 1時間後の推定差額は0.0071
# zero
# do nothing
# -------------------------------------
# ------transaction_002------
# 2018-09-17 04:01:02
# 1時間後の推定差額は0.0067
# zero
# do nothing
# -------------------------------------
# ------transaction_003------
# 2018-09-17 04:01:09
# 1時間後の推定差額は-0.0193
# sell
# do nothing
# -------------------------------------
# ------transaction_004------
# 2018-09-17 04:01:18
# 1時間後の推定差額は0.0088
# zero
# do nothing
# -------------------------------------
# ------transaction_005------
# 2018-09-17 04:01:24
# 1時間後の推定差額は-0.0063
# zero
# do nothing
# -------------------------------------
# ------transaction_006------
# 2018-09-17 04:01:31
# 1時間後の推定差額は-0.0035
# zero
# do nothing
# -------------------------------------
# ------transaction_007------
# 2018-09-17 04:01:38
# 1時間後の推定差額は0.0002
# zero
# do nothing
# -------------------------------------
# ------transaction_008------
# 2018-09-17 04:01:44
# 1時間後の推定差額は0.0059
# zero
# do nothing
# -------------------------------------
# ------transaction_009------
# 2018-09-17 04:01:50
# 1時間後の推定差額は-0.0294
# sell
# Let's sell!
# -------------------------------------
# ------transaction_010------
# 2018-09-17 04:01:58
# 1時間後の推定差額は-0.0396
# sell
# Let's sell!
# -------------------------------------
# ------transaction_011------
# 2018-09-17 04:02:04
# 1時間後の推定差額は0.0046
# zero
# do nothing
# -------------------------------------
# ------transaction_012------
# 2018-09-17 04:02:12
# 1時間後の推定差額は0.0158
# buy
# do nothing
# -------------------------------------
# ------transaction_013------
# 2018-09-17 04:02:18
# 1時間後の推定差額は-0.0082
# zero
# do nothing
# -------------------------------------
# ------transaction_014------
# 2018-09-17 04:02:25
# 1時間後の推定差額は-0.0101
# sell
# Let's sell!
# -------------------------------------
# ------transaction_015------
# 2018-09-17 04:02:31
# 1時間後の推定差額は-0.0177
# sell
# Let's sell!
# -------------------------------------
# ------transaction_016------
# 2018-09-17 04:02:38
# 1時間後の推定差額は0.0077
# zero
# do nothing
# -------------------------------------
# ------transaction_017------
# 2018-09-17 04:02:45
# 1時間後の推定差額は0.0229
# buy
# do nothing
# -------------------------------------
# ------transaction_018------
# 2018-09-17 04:02:52
# 1時間後の推定差額は0.0021
# zero
# do nothing
# -------------------------------------
# ------transaction_019------
# 2018-09-17 04:02:58
# 1時間後の推定差額は-0.0075
# zero
# do nothing
# -------------------------------------
# ------transaction_020------
# 2018-09-17 04:03:05
# 1時間後の推定差額は0.0059
# zero
# do nothing
# -------------------------------------
# ------transaction_021------
# 2018-09-17 04:03:12
# 1時間後の推定差額は-0.0216
# sell
# Let's sell!
# -------------------------------------
# ------transaction_022------
# 2018-09-17 04:03:19
# 1時間後の推定差額は0.0023
# zero
# do nothing
# -------------------------------------
# ------transaction_023------
# 2018-09-17 04:03:26
# 1時間後の推定差額は0.0342
# buy
# do nothing
# -------------------------------------
# ------transaction_024------
# 2018-09-17 04:03:32
# 1時間後の推定差額は-0.0018
# zero
# do nothing
# -------------------------------------
# ------transaction_025------
# 2018-09-17 04:03:39
# 1時間後の推定差額は-0.0012
# zero
# do nothing
# -------------------------------------
# ------transaction_026------
# 2018-09-17 04:03:46
# 1時間後の推定差額は0.0154
# buy
# do nothing
# -------------------------------------
# ------transaction_027------
# 2018-09-17 04:03:52
# 1時間後の推定差額は-0.0192
# sell
# Let's sell!
# -------------------------------------
# ------transaction_028------
# 2018-09-17 04:03:59
# 1時間後の推定差額は0.0065
# zero
# do nothing
# -------------------------------------
# ------transaction_029------
# 2018-09-17 04:04:05
# 1時間後の推定差額は-0.032
# sell
# Let's sell!
# -------------------------------------
# ------transaction_030------
# 2018-09-17 04:04:12
# 1時間後の推定差額は0.0165
# buy
# do nothing
# -------------------------------------
# ------transaction_031------
# 2018-09-17 04:04:19
# 1時間後の推定差額は-0.0159
# sell
# Let's sell!
# -------------------------------------
# ------transaction_032------
# 2018-09-17 04:04:26
# 1時間後の推定差額は-0.0122
# sell
# Let's sell!
# -------------------------------------
# ------transaction_033------
# 2018-09-17 04:04:33
# 1時間後の推定差額は0.0068
# zero
# do nothing
# -------------------------------------
# ------transaction_034------
# 2018-09-17 04:04:39
# 1時間後の推定差額は-0.029
# sell
# Let's sell!
# -------------------------------------
# ------transaction_035------
# 2018-09-17 04:04:46
# 1時間後の推定差額は-0.0102
# sell
# Let's sell!
# -------------------------------------
# ------transaction_036------
# 2018-09-17 04:04:52
# 1時間後の推定差額は0.008
# zero
# do nothing
# -------------------------------------
# ------transaction_037------
# 2018-09-17 04:04:59
# 1時間後の推定差額は-0.006
# zero
# profit:-0.1
# do nothing
# -------------------------------------
# ------transaction_038------
# 2018-09-17 04:05:06
# 1時間後の推定差額は-0.0009
# zero
# profit:0.1
# do nothing
# -------------------------------------
# ------transaction_039------
# 2018-09-17 04:05:13
# 1時間後の推定差額は-0.0251
# sell
# Let's sell!
# -------------------------------------
# ------transaction_040------
# 2018-09-17 04:05:20
# 1時間後の推定差額は-0.01
# zero
# do nothing
# -------------------------------------
# ------transaction_041------
# 2018-09-17 04:05:31
# 1時間後の推定差額は0.0034
# zero
# profit:-0.1
# do nothing
# -------------------------------------
# ------transaction_042------
# 2018-09-17 04:05:38
# 1時間後の推定差額は0.0106
# buy
# profit:-0.1
# do nothing
# -------------------------------------
# ------transaction_043------
# 2018-09-17 04:05:45
# 1時間後の推定差額は-0.0361
# sell
# Let's sell!
# -------------------------------------
# ------transaction_044------
# 2018-09-17 04:05:52
# 1時間後の推定差額は-0.0024
# zero
# do nothing
# -------------------------------------
# ------transaction_045------
# 2018-09-17 04:05:59
# 1時間後の推定差額は0.0115
# buy
# do nothing
# -------------------------------------
# ------transaction_046------
# 2018-09-17 04:06:05
# 1時間後の推定差額は-0.0025
# zero
# do nothing
# -------------------------------------
# ------transaction_047------
# 2018-09-17 04:06:13
# 1時間後の推定差額は0.0015
# zero
# do nothing
# -------------------------------------
# ------transaction_048------
# 2018-09-17 04:06:20
# 1時間後の推定差額は-0.0107
# sell
# profit:-1
# Let's sell!
# -------------------------------------
# ------transaction_049------
# 2018-09-17 04:06:27
# 1時間後の推定差額は0.0134
# buy
# do nothing
# -------------------------------------
# ------transaction_050------
# 2018-09-17 04:06:34
# 1時間後の推定差額は0.0012
# zero
# do nothing
# -------------------------------------
# ------transaction_051------
# 2018-09-17 04:06:40
# 1時間後の推定差額は-0.0242
# sell
# Let's sell!
# -------------------------------------
# ------transaction_052------
# 2018-09-17 04:06:47
# 1時間後の推定差額は-0.0243
# sell
# Let's sell!
# -------------------------------------
# ------transaction_053------
# 2018-09-17 04:06:56
# 1時間後の推定差額は0.0208
# buy
# profit:-1.3
# do nothing
# -------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-bf6e5f7b4083> in <module>()
#      69                'pred_side': pred_side}
#      70     logs.append(log)
# ---> 71     time.sleep(5) #5秒に設定中
#
# KeyboardInterrupt:

# %%
# Out:
# {'time': '2018-09-17 04:00:33',
#  'current_ask_price': 111.975,
#  'current_bid_price': 111.971,
#  'pred_delta': 0.0009388279286213219,
#  'pred_side': 'zero'}

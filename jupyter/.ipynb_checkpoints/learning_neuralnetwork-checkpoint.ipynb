# %%
# %%HTML
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %% [markdown]
# ### Library

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

import renom as rm
from renom.optimizer import Adam, Adagrad
from renom.cuda import set_cuda_active
# if you would like to use GPU, set True, otherwise you should be set to False
set_cuda_active(False)

# %%
def create_dataset(data, look_back, pred_length):
    exp, target = [], []
    for i in range(len(data) - look_back - pred_length):
        exp.append(data[i : i+look_back, :])
        target.append(data[i + look_back : i + look_back + pred_length, 9].T[0])
        
    n_features = np.array(exp).shape[2]
    exp = np.reshape(np.array(exp), [-1, look_back, n_features])
    target = np.reshape(np.array(target), [-1, 1])
    return exp, target

# %%
def split_data(X, y, test_size=0.1):
    pos = int(round(len(X) * (1-test_size)))
    X_train, y_train = X[:pos], y[:pos]
    X_test, y_test = X[pos:], y[pos:]
    return X_train, y_train, X_test, y_test, pos

# %%
gran = 'H1'

# %%
with open('../intermediate_data/prep_data_{}.pickle'.format(gran), mode='rb') as f:
    df = pickle.load(f)

# %%
df_std = df.copy()
stds, means = [], []
for col in df:
    std = df[col].std()
    mean = df[col].mean()
    df_std[col] = (df[col] - mean) / std
    stds.append(std)
    means.append(mean)
data = np.array(df_std)

# %%
look_back = 10
pred_length = 1
X, y = create_dataset(data, look_back, pred_length)

# %%
X_train, y_train, X_test, y_test, pos = split_data(X, y)

# %%
sequential = rm.Sequential([
    rm.Lstm(30),
    rm.Lstm(10),
    rm.Dense(pred_length)
])

# %%
batch_size = 1024
epoch = 1000
N = len(X_train)
T = X_train.shape[1]

learning_curve = []
test_learning_curve = []
optimizer = Adagrad()
for i in range(epoch):
    loss = 0
    test_loss = 0
    perm = np.random.permutation(N)
    for j in range(N//batch_size):
        train_batch = X_train[perm[j*batch_size : (j+1)*batch_size]]
        response_batch = y_train[perm[j*batch_size : (j+1)*batch_size]]
        l = 0
        with sequential.train():
            for t in range(T):
                z = sequential(train_batch[:, t, :])
                l = rm.mse(z, response_batch)
            sequential.truncate()
        l.grad().update(optimizer)
        loss += l.as_ndarray()
    loss = loss / (N // batch_size)
    l_test = 0
    for t in range(T):
        z = sequential(X_test[:, t, :])
        l_test = rm.mse(z, y_test)
    sequential.truncate()
    test_loss += l_test.as_ndarray()
    if i % 10 == 0:
        print("epoch:{:04d} loss:{:.5f} test_loss:{:.5f}".format(i, loss, test_loss))
    learning_curve.append(loss)
    test_learning_curve.append(test_loss)
# Out:
# epoch:0000 loss:0.52767 test_loss:0.29305
# epoch:0010 loss:0.51366 test_loss:0.29209
# epoch:0020 loss:0.50064 test_loss:0.28009
# epoch:0030 loss:0.49536 test_loss:0.27902
# epoch:0040 loss:0.49197 test_loss:0.27991
# epoch:0050 loss:0.49102 test_loss:0.27784
# epoch:0060 loss:0.48978 test_loss:0.27816
# epoch:0070 loss:0.48831 test_loss:0.27935
# epoch:0080 loss:0.48609 test_loss:0.27737
# epoch:0090 loss:0.48546 test_loss:0.27779
# epoch:0100 loss:0.48437 test_loss:0.27924
# epoch:0110 loss:0.48377 test_loss:0.27758
# epoch:0120 loss:0.48180 test_loss:0.27783
# epoch:0130 loss:0.48106 test_loss:0.27779
# epoch:0140 loss:0.47991 test_loss:0.27793
# epoch:0150 loss:0.47920 test_loss:0.27760
# epoch:0160 loss:0.47875 test_loss:0.27769
# epoch:0170 loss:0.47782 test_loss:0.27760
# epoch:0180 loss:0.47655 test_loss:0.27753
# epoch:0190 loss:0.47621 test_loss:0.27764
# epoch:0200 loss:0.47482 test_loss:0.27838
# epoch:0210 loss:0.47401 test_loss:0.27780
# epoch:0220 loss:0.47367 test_loss:0.27835
# epoch:0230 loss:0.47293 test_loss:0.27782
# epoch:0240 loss:0.47194 test_loss:0.27825
# epoch:0250 loss:0.47121 test_loss:0.27824
# epoch:0260 loss:0.47089 test_loss:0.27785
# epoch:0270 loss:0.47018 test_loss:0.27807
# epoch:0280 loss:0.46922 test_loss:0.27898
# epoch:0290 loss:0.46826 test_loss:0.27889
# epoch:0300 loss:0.46811 test_loss:0.27843
# epoch:0310 loss:0.46706 test_loss:0.27871
# epoch:0320 loss:0.46650 test_loss:0.27899
# epoch:0330 loss:0.46561 test_loss:0.28063
# epoch:0340 loss:0.46516 test_loss:0.27875
# epoch:0350 loss:0.46405 test_loss:0.27910
# epoch:0360 loss:0.46345 test_loss:0.27926
# epoch:0370 loss:0.46269 test_loss:0.27939
# epoch:0380 loss:0.46247 test_loss:0.27936
# epoch:0390 loss:0.46174 test_loss:0.27956
# epoch:0400 loss:0.46132 test_loss:0.27956
# epoch:0410 loss:0.46028 test_loss:0.28059
# epoch:0420 loss:0.45961 test_loss:0.27972
# epoch:0430 loss:0.45936 test_loss:0.28041
# epoch:0440 loss:0.45852 test_loss:0.28074
# epoch:0450 loss:0.45748 test_loss:0.28011
# epoch:0460 loss:0.45755 test_loss:0.28001
# epoch:0470 loss:0.45722 test_loss:0.28126
# epoch:0480 loss:0.45623 test_loss:0.28142
# epoch:0490 loss:0.45587 test_loss:0.28158
# epoch:0500 loss:0.45493 test_loss:0.28083
# epoch:0510 loss:0.45478 test_loss:0.28074
# epoch:0520 loss:0.45385 test_loss:0.28172
# epoch:0530 loss:0.45351 test_loss:0.28190
# epoch:0540 loss:0.45296 test_loss:0.28144
# epoch:0550 loss:0.45276 test_loss:0.28206
# epoch:0560 loss:0.45184 test_loss:0.28308
# epoch:0570 loss:0.45130 test_loss:0.28231
# epoch:0580 loss:0.45129 test_loss:0.28127
# epoch:0590 loss:0.45053 test_loss:0.28226
# epoch:0600 loss:0.44982 test_loss:0.28286
# epoch:0610 loss:0.44931 test_loss:0.28232
# epoch:0620 loss:0.44917 test_loss:0.28279
# epoch:0630 loss:0.44881 test_loss:0.28249
# epoch:0640 loss:0.44830 test_loss:0.28368
# epoch:0650 loss:0.44719 test_loss:0.28267
# epoch:0660 loss:0.44727 test_loss:0.28268
# epoch:0670 loss:0.44436 test_loss:0.28243
# epoch:0680 loss:0.44661 test_loss:0.28267
# epoch:0690 loss:0.44559 test_loss:0.28284
# epoch:0700 loss:0.44556 test_loss:0.28300
# epoch:0710 loss:0.44528 test_loss:0.28356
# epoch:0720 loss:0.44439 test_loss:0.28314
# epoch:0730 loss:0.44424 test_loss:0.28297
# epoch:0740 loss:0.44355 test_loss:0.28393
# epoch:0750 loss:0.44370 test_loss:0.28454
# epoch:0760 loss:0.44295 test_loss:0.28350
# epoch:0770 loss:0.44186 test_loss:0.28545
# epoch:0780 loss:0.44205 test_loss:0.28413
# epoch:0790 loss:0.44153 test_loss:0.28465
# epoch:0800 loss:0.44138 test_loss:0.28399
# epoch:0810 loss:0.44109 test_loss:0.28403
# epoch:0820 loss:0.43991 test_loss:0.28448
# epoch:0830 loss:0.43984 test_loss:0.28519
# epoch:0840 loss:0.43972 test_loss:0.28391
# epoch:0850 loss:0.43917 test_loss:0.28435
# epoch:0860 loss:0.43897 test_loss:0.28387
# epoch:0870 loss:0.43860 test_loss:0.28472
# epoch:0880 loss:0.43825 test_loss:0.28501
# epoch:0890 loss:0.43769 test_loss:0.28447
# epoch:0900 loss:0.43743 test_loss:0.28436
# epoch:0910 loss:0.43714 test_loss:0.28509
# epoch:0920 loss:0.43698 test_loss:0.28470
# epoch:0930 loss:0.43657 test_loss:0.28447
# epoch:0940 loss:0.43584 test_loss:0.28550
# epoch:0950 loss:0.43555 test_loss:0.28530
# epoch:0960 loss:0.43511 test_loss:0.28661
# epoch:0970 loss:0.43502 test_loss:0.28614
# epoch:0980 loss:0.43500 test_loss:0.28571
# epoch:0990 loss:0.43439 test_loss:0.28599

# %%
plt.figure(figsize=(10, 4))
plt.plot(learning_curve, label='loss')
plt.plot(test_learning_curve, label='test_loss', alpha=0.6)
plt.title('Learning curve')
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.ylim(0, 2)
plt.legend()
plt.grid()

# %%
# predict test value
for t in range(T):
    y_test_pred = sequential(X_test[:, t, :])
sequential.truncate()
for t in range(T):
    y_train_pred = sequential(X_train[:, t, :])
sequential.truncate()

# # convert standardized heating-load to its original unit
y_train = y_train * stds[9] + means[9]
y_train_pred = y_train_pred * stds[9] + means[9]
y_test = y_test * stds[9] + means[9]
y_test_pred = y_test_pred * stds[9] + means[9]

# Root mean squared error
print("Root mean squared error:{}".format(np.sqrt(mean_squared_error(y_test, y_test_pred))))

ulim = 4
llim = -4
plt.figure(figsize=(8, 8))
plt.plot([llim, ulim], [llim, ulim], c='k', alpha=0.6) # diagonal line
plt.scatter(y_train, y_train_pred, label = 'train')
plt.scatter(y_test, y_test_pred, label = 'test')
plt.xlim(llim, ulim)
plt.ylim(llim, ulim)
plt.xlabel('Actual', fontsize=16)
plt.ylabel('Prediction', fontsize=16)
plt.legend()
plt.grid()
# Out:
# Root mean squared error:0.10381677615976526

# %%
train_price = []
tr_p = df['closeAsk'][0]
for v in y_train:
    tr_p += v[0]
    train_price.append(tr_p)
    
train_pred_price = []
tr_pr_p = df['closeAsk'][0]
for v in y_train_pred:
    tr_pr_p += v[0]
    train_pred_price.append(tr_pr_p)

test_price = []
te_p = df['closeAsk'][y_train.shape[0]]
for v in y_test:
    te_p += v[0]
    test_price.append(te_p)
    
test_pred_price = []
te_pr_p = df['closeAsk'][y_train.shape[0]]
for v in y_test_pred:
    te_pr_p += v[0]
    test_pred_price.append(te_pr_p)

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[:pos].index, y_train, label = 'train_actual')
plt.plot(df_std[:pos].index, y_train_pred, label = 'train_prediction')
plt.ylabel('delta_close')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test, label = 'test_actual')
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test_pred, label = 'test_prediction')
plt.ylabel('delta_close')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test, label = 'test_actual')
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test_pred, label = 'test_prediction')
plt.ylabel('delta_close')
plt.xlim('2017-07-01','2017-10-01')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[:pos].index, train_price, label = 'train_actual')
plt.plot(df_std[:pos].index, train_pred_price, label = 'train_prediction')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, test_price, label = 'test_actual')
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, test_pred_price, label = 'test_prediction')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
true_updown = y_train
true_updown[true_updown > 0.1] = 1
true_updown[true_updown < -0.1] = -1
true_updown[(true_updown > -0.1) & (true_updown < 0.1)] = 0

pred_updown = np.array(y_train_pred)
pred_updown[pred_updown > 0.1] = 1
pred_updown[pred_updown < -0.1] = -1
pred_updown[(pred_updown > -0.1) & (pred_updown < 0.1)] = 0

df_updown = pd.DataFrame(index = df_std[:pos].index, columns = ['true', 'pred'])
df_updown['true'] = true_updown
df_updown['pred'] = pred_updown
df_updown['error'] = np.zeros(df_updown.shape[0])
df_updown.loc[df_updown['true'] == df_updown['pred'],'error'] = 1
df_updown.loc[df_updown['true'] != df_updown['pred'],'error'] = 0
print('correct = ', df_updown[df_updown['error'] == 1].shape[0])
print('not correct = ', df_updown[df_updown['error'] == 0].shape[0])
# Out:
# correct =  46762
# not correct =  18840

# %%
true_updown = y_test
true_updown[true_updown > 0.1] = 1
true_updown[true_updown < -0.1] = -1
true_updown[(true_updown > -0.1) & (true_updown < 0.1)] = 0

pred_updown = np.array(y_test_pred)
pred_updown[pred_updown > 0.1] = 1
pred_updown[pred_updown < -0.1] = -1
pred_updown[(pred_updown > -0.1) & (pred_updown < 0.1)] = 0

df_updown = pd.DataFrame(index = df_std[pos:-1 * (look_back + pred_length)].index, columns = ['true', 'pred'])
df_updown['true'] = true_updown
df_updown['pred'] = pred_updown
df_updown['error'] = np.zeros(df_updown.shape[0])
df_updown.loc[df_updown['true'] == df_updown['pred'],'error'] = 1
df_updown.loc[df_updown['true'] != df_updown['pred'],'error'] = 0
print('correct = ', df_updown[df_updown['error'] == 1].shape[0])
print('not correct = ', df_updown[df_updown['error'] == 0].shape[0])
# Out:
# correct =  5543
# not correct =  1746

# %%
sequential.save("../model/lstm_{}_{}.h5".format(gran, look_back))

# %%
with open('../model/std_scalor_{}.pickle'.format(gran), mode='wb') as f:
    pickle.dump(stds, f)

# %%
with open('../model/mean_scalor_{}.pickle'.format(gran), mode='wb') as f:
    pickle.dump(means, f)

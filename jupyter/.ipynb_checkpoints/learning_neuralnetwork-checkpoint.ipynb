# %%
# %%HTML
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %% [markdown]
# ### Library

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

import renom as rm
from renom.optimizer import Adam
from renom.cuda import set_cuda_active
# if you would like to use GPU, set True, otherwise you should be set to False
set_cuda_active(False)

# %%
def create_dataset(data, look_back, pred_length):
    exp, target = [], []
    for i in range(len(data) - look_back - pred_length):
        exp.append(data[i : i+look_back, :])
        target.append(data[i + look_back : i + look_back + pred_length, 9].T[0])
        
    n_features = np.array(exp).shape[2]
    exp = np.reshape(np.array(exp), [-1, look_back, n_features])
    target = np.reshape(np.array(target), [-1, 1])
    return exp, target

# %%
def split_data(X, y, test_size=0.1):
    pos = int(round(len(X) * (1-test_size)))
    X_train, y_train = X[:pos], y[:pos]
    X_test, y_test = X[pos:], y[pos:]
    return X_train, y_train, X_test, y_test, pos

# %%
gran = 'H1'

# %%
with open('../intermediate_data/prep_data_{}.pickle'.format(gran), mode='rb') as f:
    df = pickle.load(f)

# %%
df_std = df.copy()
stds, means = [], []
for col in df:
    std = df[col].std()
    mean = df[col].mean()
    df_std[col] = (df[col] - mean) / std
    stds.append(std)
    means.append(mean)
data = np.array(df_std)

# %%
look_back = 10
pred_length = 1
X, y = create_dataset(data, look_back, pred_length)

# %%
X_train, y_train, X_test, y_test, pos = split_data(X, y)

# %%
sequential = rm.Sequential([
    rm.Lstm(30),
    rm.Lstm(10),
    rm.Dense(pred_length)
])

# %%
batch_size = 1024
epoch = 1000
N = len(X_train)
T = X_train.shape[1]

learning_curve = []
test_learning_curve = []
optimizer = Adam(lr=0.001)
for i in range(epoch):
    loss = 0
    test_loss = 0
    perm = np.random.permutation(N)
    for j in range(N//batch_size):
        train_batch = X_train[perm[j*batch_size : (j+1)*batch_size]]
        response_batch = y_train[perm[j*batch_size : (j+1)*batch_size]]
        l = 0
        with sequential.train():
            for t in range(T):
                z = sequential(train_batch[:, t, :])
                l = rm.mse(z, response_batch)
            sequential.truncate()
        l.grad().update(optimizer)
        loss += l.as_ndarray()
    loss = loss / (N // batch_size)
    l_test = 0
    for t in range(T):
        z = sequential(X_test[:, t, :])
        l_test = rm.mse(z, y_test)
    sequential.truncate()
    test_loss += l_test.as_ndarray()
    if i % 10 == 0:
        print("epoch:{:04d} loss:{:.5f} test_loss:{:.5f}".format(i, loss, test_loss))
    learning_curve.append(loss)
    test_learning_curve.append(test_loss)
# Out:
# epoch:0000 loss:0.52502 test_loss:0.29281
# epoch:0010 loss:0.50270 test_loss:0.28489
# epoch:0020 loss:0.49501 test_loss:0.27857
# epoch:0030 loss:0.48820 test_loss:0.27923
# epoch:0040 loss:0.48153 test_loss:0.28020
# epoch:0050 loss:0.47709 test_loss:0.27925
# epoch:0060 loss:0.47009 test_loss:0.28169
# epoch:0070 loss:0.46512 test_loss:0.28074
# epoch:0080 loss:0.45908 test_loss:0.28336
# epoch:0090 loss:0.44957 test_loss:0.28572
# epoch:0100 loss:0.44182 test_loss:0.28573
# epoch:0110 loss:0.43739 test_loss:0.28668
# epoch:0120 loss:0.43085 test_loss:0.28708
# epoch:0130 loss:0.42397 test_loss:0.28679
# epoch:0140 loss:0.42005 test_loss:0.28923
# epoch:0150 loss:0.41576 test_loss:0.28890
# epoch:0160 loss:0.41278 test_loss:0.28458
# epoch:0170 loss:0.40270 test_loss:0.28942
# epoch:0180 loss:0.39842 test_loss:0.29039
# epoch:0190 loss:0.39831 test_loss:0.28790
# epoch:0200 loss:0.39102 test_loss:0.29314
# epoch:0210 loss:0.38831 test_loss:0.29044
# epoch:0220 loss:0.38473 test_loss:0.29269
# epoch:0230 loss:0.38033 test_loss:0.29318
# epoch:0240 loss:0.37631 test_loss:0.29200
# epoch:0250 loss:0.37379 test_loss:0.29360
# epoch:0260 loss:0.37637 test_loss:0.29752
# epoch:0270 loss:0.36901 test_loss:0.29967
# epoch:0280 loss:0.36513 test_loss:0.29684
# epoch:0290 loss:0.36483 test_loss:0.29449
# epoch:0300 loss:0.36020 test_loss:0.29949
# epoch:0310 loss:0.36522 test_loss:0.29429
# epoch:0320 loss:0.35817 test_loss:0.29514
# epoch:0330 loss:0.35584 test_loss:0.29568
# epoch:0340 loss:0.35751 test_loss:0.29935
# epoch:0350 loss:0.35095 test_loss:0.29501
# epoch:0360 loss:0.35298 test_loss:0.30129
# epoch:0370 loss:0.34976 test_loss:0.30060
# epoch:0380 loss:0.34855 test_loss:0.30005
# epoch:0390 loss:0.34524 test_loss:0.30114
# epoch:0400 loss:0.35061 test_loss:0.30199
# epoch:0410 loss:0.34136 test_loss:0.30244
# epoch:0420 loss:0.34170 test_loss:0.30844
# epoch:0430 loss:0.34233 test_loss:0.30578
# epoch:0440 loss:0.34363 test_loss:0.30681
# epoch:0450 loss:0.33602 test_loss:0.30546
# epoch:0460 loss:0.34814 test_loss:0.30310
# epoch:0470 loss:0.33650 test_loss:0.31112
# epoch:0480 loss:0.33455 test_loss:0.30668
# epoch:0490 loss:0.34067 test_loss:0.31259
# epoch:0500 loss:0.33241 test_loss:0.31091
# epoch:0510 loss:0.33131 test_loss:0.31337
# epoch:0520 loss:0.32993 test_loss:0.30910
# epoch:0530 loss:0.32776 test_loss:0.31304
# epoch:0540 loss:0.32861 test_loss:0.31677
# epoch:0550 loss:0.33091 test_loss:0.31303
# epoch:0560 loss:0.32752 test_loss:0.31659
# epoch:0570 loss:0.32987 test_loss:0.31567
# epoch:0580 loss:0.32251 test_loss:0.31772
# epoch:0590 loss:0.32181 test_loss:0.31616
# epoch:0600 loss:0.32598 test_loss:0.31918
# epoch:0610 loss:0.32398 test_loss:0.31631
# epoch:0620 loss:0.32186 test_loss:0.31945
# epoch:0630 loss:0.32532 test_loss:0.32408
# epoch:0640 loss:0.32009 test_loss:0.31960
# epoch:0650 loss:0.31783 test_loss:0.32103
# epoch:0660 loss:0.31943 test_loss:0.32317
# epoch:0670 loss:0.31602 test_loss:0.32330
# epoch:0680 loss:0.31454 test_loss:0.32422
# epoch:0690 loss:0.31399 test_loss:0.32836
# epoch:0700 loss:0.31237 test_loss:0.33179
# epoch:0710 loss:0.31346 test_loss:0.32741
# epoch:0720 loss:0.31404 test_loss:0.32400
# epoch:0730 loss:0.31424 test_loss:0.31747
# epoch:0740 loss:0.31141 test_loss:0.31954
# epoch:0750 loss:0.31197 test_loss:0.33225
# epoch:0760 loss:0.31132 test_loss:0.32658
# epoch:0770 loss:0.32707 test_loss:0.32075
# epoch:0780 loss:0.30905 test_loss:0.32634
# epoch:0790 loss:0.30780 test_loss:0.32845
# epoch:0800 loss:0.31006 test_loss:0.32352
# epoch:0810 loss:0.31462 test_loss:0.33114
# epoch:0820 loss:0.30788 test_loss:0.33034
# epoch:0830 loss:0.30777 test_loss:0.33422
# epoch:0840 loss:0.30575 test_loss:0.33455
# epoch:0850 loss:0.30776 test_loss:0.32739
# epoch:0860 loss:0.31920 test_loss:0.32397
# epoch:0870 loss:0.30387 test_loss:0.32827
# epoch:0880 loss:0.30442 test_loss:0.33959
# epoch:0890 loss:0.30846 test_loss:0.32895
# epoch:0900 loss:0.30100 test_loss:0.33768
# epoch:0910 loss:0.30249 test_loss:0.33540
# epoch:0920 loss:0.30153 test_loss:0.33757
# epoch:0930 loss:0.30215 test_loss:0.33108
# epoch:0940 loss:0.30526 test_loss:0.34020
# epoch:0950 loss:0.30043 test_loss:0.33297
# epoch:0960 loss:0.30077 test_loss:0.34147
# epoch:0970 loss:0.30165 test_loss:0.33428
# epoch:0980 loss:0.29991 test_loss:0.33674
# epoch:0990 loss:0.29972 test_loss:0.33028

# %%
plt.figure(figsize=(10, 4))
plt.plot(learning_curve, label='loss')
plt.plot(test_learning_curve, label='test_loss', alpha=0.6)
plt.title('Learning curve')
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.ylim(0, 2)
plt.legend()
plt.grid()

# %%
X_test.shape
# Out:
# (7289, 10, 33)

# %%
# predict test value
for t in range(T):
    y_test_pred = sequential(X_test[:, t, :])
sequential.truncate()
for t in range(T):
    y_train_pred = sequential(X_train[:, t, :])
sequential.truncate()

# # convert standardized heating-load to its original unit
y_train = y_train * stds[9] + means[9]
y_train_pred = y_train_pred * stds[9] + means[9]
y_test = y_test * stds[9] + means[9]
y_test_pred = y_test_pred * stds[9] + means[9]

# Root mean squared error
print("Root mean squared error:{}".format(np.sqrt(mean_squared_error(y_test, y_test_pred))))

ulim = 4
llim = -4
plt.figure(figsize=(8, 8))
plt.plot([llim, ulim], [llim, ulim], c='k', alpha=0.6) # diagonal line
plt.scatter(y_train, y_train_pred, label = 'train')
plt.scatter(y_test, y_test_pred, label = 'test')
plt.xlim(llim, ulim)
plt.ylim(llim, ulim)
plt.xlabel('Actual', fontsize=16)
plt.ylabel('Prediction', fontsize=16)
plt.legend()
plt.grid()
# Out:
# Root mean squared error:0.11169063705800325

# %%
train_price = []
tr_p = df['closeAsk'][0]
for v in y_train:
    tr_p += v[0]
    train_price.append(tr_p)
    
train_pred_price = []
tr_pr_p = df['closeAsk'][0]
for v in y_train_pred:
    tr_pr_p += v[0]
    train_pred_price.append(tr_pr_p)

test_price = []
te_p = df['closeAsk'][y_train.shape[0]]
for v in y_test:
    te_p += v[0]
    test_price.append(te_p)
    
test_pred_price = []
te_pr_p = df['closeAsk'][y_train.shape[0]]
for v in y_test_pred:
    te_pr_p += v[0]
    test_pred_price.append(te_pr_p)

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[:pos].index, y_train, label = 'train_actual')
plt.plot(df_std[:pos].index, y_train_pred, label = 'train_prediction')
plt.ylabel('delta_close')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test, label = 'test_actual')
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, y_test_pred, label = 'test_prediction')
plt.ylabel('delta_close')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[:pos].index, train_price, label = 'train_actual')
plt.plot(df_std[:pos].index, train_pred_price, label = 'train_prediction')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, test_price, label = 'test_actual')
plt.plot(df_std[pos:-1 * (look_back + pred_length)].index, test_pred_price, label = 'test_prediction')
plt.ylabel('price')
plt.legend()
plt.show()

# %%
true_updown = y_train
true_updown[true_updown > 0.1] = 1
true_updown[true_updown < -0.1] = -1
true_updown[(true_updown > -0.1) & (true_updown < 0.1)] = 0

pred_updown = np.array(y_train_pred)
pred_updown[pred_updown > 0.1] = 1
pred_updown[pred_updown < -0.1] = -1
pred_updown[(pred_updown > -0.1) & (pred_updown < 0.1)] = 0

df_updown = pd.DataFrame(index = df_std[:pos].index, columns = ['true', 'pred'])
df_updown['true'] = true_updown
df_updown['pred'] = pred_updown
df_updown['error'] = np.zeros(df_updown.shape[0])
df_updown.loc[df_updown['true'] == df_updown['pred'],'error'] = 1
df_updown.loc[df_updown['true'] != df_updown['pred'],'error'] = 0
print('correct = ', df_updown[df_updown['error'] == 1].shape[0])
print('not correct = ', df_updown[df_updown['error'] == 0].shape[0])
# Out:
# correct =  47253
# not correct =  18349

# %%
true_updown = y_test
true_updown[true_updown > 0.1] = 1
true_updown[true_updown < -0.1] = -1
true_updown[(true_updown > -0.1) & (true_updown < 0.1)] = 0

pred_updown = np.array(y_test_pred)
pred_updown[pred_updown > 0.1] = 1
pred_updown[pred_updown < -0.1] = -1
pred_updown[(pred_updown > -0.1) & (pred_updown < 0.1)] = 0

df_updown = pd.DataFrame(index = df_std[pos:-1 * (look_back + pred_length)].index, columns = ['true', 'pred'])
df_updown['true'] = true_updown
df_updown['pred'] = pred_updown
df_updown['error'] = np.zeros(df_updown.shape[0])
df_updown.loc[df_updown['true'] == df_updown['pred'],'error'] = 1
df_updown.loc[df_updown['true'] != df_updown['pred'],'error'] = 0
print('correct = ', df_updown[df_updown['error'] == 1].shape[0])
print('not correct = ', df_updown[df_updown['error'] == 0].shape[0])
# Out:
# correct =  5465
# not correct =  1824
